# %%
# !pip install jupyter_require
# !pip install git+git://github.com/CermakM/lab@dynamic-hierarchical-layout#egg=thoth-lab
# Out:
# Requirement already satisfied: jupyter_require in /opt/app-root/lib/python3.6/site-packages (0.1.8)
# Requirement already satisfied: traitlets==4.3.2 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (4.3.2)
# Requirement already satisfied: ipython==7.3.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (7.3.0)
# Requirement already satisfied: jedi==0.13.3 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (0.13.3)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (0.7.5)
# Requirement already satisfied: backcall==0.1.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (0.1.0)
# Requirement already satisfied: parso==0.3.4 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (0.3.4)
# Requirement already satisfied: pexpect==4.6.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (4.6.0)
# Requirement already satisfied: decorator==4.3.2 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (4.3.2)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (0.2.0)
# Requirement already satisfied: pygments==2.3.1 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (2.3.1)
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (0.6.0)
# Requirement already satisfied: six==1.12.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (1.12.0)
# Requirement already satisfied: wcwidth==0.1.7 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (0.1.7)
# Requirement already satisfied: prompt-toolkit==2.0.9 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require) (2.0.9)
# Requirement already satisfied: setuptools>=18.5 in /opt/app-root/lib/python3.6/site-packages (from ipython==7.3.0->jupyter_require) (40.6.2)
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: thoth-lab from git+git://github.com/CermakM/lab@dynamic-hierarchical-layout#egg=thoth-lab in /opt/app-root/lib/python3.6/site-packages/thoth_lab-0.0.3-py3.6.egg (0.0.3)
# Requirement already satisfied: gremlinpython in /opt/app-root/lib/python3.6/site-packages/gremlinpython-3.4.0-py3.6.egg (from thoth-lab) (3.4.0)
# Requirement already satisfied: jupyter_require in /opt/app-root/lib/python3.6/site-packages (from thoth-lab) (0.1.8)
# Requirement already satisfied: networkx in /opt/app-root/lib/python3.6/site-packages (from thoth-lab) (2.2)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.6/site-packages (from thoth-lab) (2.20.1)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.6/site-packages (from thoth-lab) (0.24.1)
# Requirement already satisfied: plotly in /opt/app-root/lib/python3.6/site-packages/plotly-3.7.0-py3.6.egg (from thoth-lab) (3.7.0)
# Requirement already satisfied: aenum>=1.4.5 in /opt/app-root/lib/python3.6/site-packages/aenum-2.1.2-py3.6.egg (from gremlinpython->thoth-lab) (2.1.2)
# Requirement already satisfied: six>=1.10.0 in /opt/app-root/lib/python3.6/site-packages (from gremlinpython->thoth-lab) (1.12.0)
# Collecting tornado<5.0,>=4.4.1 (from gremlinpython->thoth-lab)
#   Downloading https://files.pythonhosted.org/packages/e3/7b/e29ab3d51c8df66922fea216e2bddfcb6430fb29620e5165b16a216e0d3c/tornado-4.5.3.tar.gz (484kB)
#     100% |████████████████████████████████| 491kB 3.1MB/s ta 0:00:0101
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (0.6.0)
# Requirement already satisfied: backcall==0.1.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (0.1.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (0.7.5)
# Requirement already satisfied: wcwidth==0.1.7 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (0.1.7)
# Requirement already satisfied: decorator==4.3.2 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (4.3.2)
# Requirement already satisfied: prompt-toolkit==2.0.9 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (2.0.9)
# Requirement already satisfied: ipython==7.3.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (7.3.0)
# Requirement already satisfied: parso==0.3.4 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (0.3.4)
# Requirement already satisfied: pexpect==4.6.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (4.6.0)
# Requirement already satisfied: pygments==2.3.1 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (2.3.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (0.2.0)
# Requirement already satisfied: traitlets==4.3.2 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (4.3.2)
# Requirement already satisfied: jedi==0.13.3 in /opt/app-root/lib/python3.6/site-packages (from jupyter_require->thoth-lab) (0.13.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.6/site-packages (from requests->thoth-lab) (2018.10.15)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/app-root/lib/python3.6/site-packages (from requests->thoth-lab) (1.24.1)
# Requirement already satisfied: idna<2.8,>=2.5 in /opt/app-root/lib/python3.6/site-packages (from requests->thoth-lab) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/app-root/lib/python3.6/site-packages (from requests->thoth-lab) (3.0.4)
# Requirement already satisfied: pytz>=2011k in /opt/app-root/lib/python3.6/site-packages (from pandas->thoth-lab) (2018.7)
# Requirement already satisfied: numpy>=1.12.0 in /opt/app-root/lib/python3.6/site-packages (from pandas->thoth-lab) (1.15.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/app-root/lib/python3.6/site-packages (from pandas->thoth-lab) (2.7.5)
# Requirement already satisfied: nbformat>=4.2 in /opt/app-root/lib/python3.6/site-packages (from plotly->thoth-lab) (4.4.0)
# Requirement already satisfied: retrying>=1.3.3 in /opt/app-root/lib/python3.6/site-packages/retrying-1.3.3-py3.6.egg (from plotly->thoth-lab) (1.3.3)
# Requirement already satisfied: setuptools>=18.5 in /opt/app-root/lib/python3.6/site-packages (from ipython==7.3.0->jupyter_require->thoth-lab) (40.6.2)
# Requirement already satisfied: jupyter-core in /opt/app-root/lib/python3.6/site-packages (from nbformat>=4.2->plotly->thoth-lab) (4.4.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/app-root/lib/python3.6/site-packages (from nbformat>=4.2->plotly->thoth-lab) (2.6.0)
# Installing collected packages: tornado
#   Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Running setup.py install for tornado ... done
# Successfully installed tornado-4.5.3
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import jupyter_require
import pandas as pd

from thoth.lab.viz import init_notebook_mode
from thoth.lab.viz import iplot, plot

from thoth.lab.utils import str_join

# %%
init_notebook_mode()

# %% [markdown]
# ---

# %%
df = pd.DataFrame([
    {'name': "root",},
    {'name': "tensorflow", 'parent': "root", 'package_version': '1.4.0'},
    {'name': "tensorflow", 'parent': "root", 'package_version': '1.5.0'},
    {'name': "numpy", 'parent': "tensorflow", 'parent_version': '1.4.0', 'package_version': '1.0.0'},
    {'name': "numpy", 'parent': "tensorflow", 'parent_version': '1.4.0', 'package_version': '1.1.0'},
    {'name': "numpy", 'parent': "tensorflow", 'parent_version': '1.5.0', 'package_version': '1.2.0'},
])

df['source'] = str_join(df, ['parent', 'parent_version'], '==')
df['target'] = str_join(df, ['name', 'package_version'], '==')
df
# Out:
#          name package_version      parent parent_version             source  \
# 0        root             NaN         NaN            NaN
# 1  tensorflow           1.4.0        root            NaN               root
# 2  tensorflow           1.5.0        root            NaN               root
# 3       numpy           1.0.0  tensorflow          1.4.0  tensorflow==1.4.0
# 4       numpy           1.1.0  tensorflow          1.4.0  tensorflow==1.4.0
# 5       numpy           1.2.0  tensorflow          1.5.0  tensorflow==1.5.0
#
#               target
# 0               root
# 1  tensorflow==1.4.0
# 2  tensorflow==1.5.0
# 3       numpy==1.0.0
# 4       numpy==1.1.0
# 5       numpy==1.2.0

# %% [markdown]
# # Static plot

# %%
plot(df)

# %% [markdown]
# # Dynamic (interactive) plot

# %% [markdown]
# ### Highlights
#
# | feature | action |
# | --- | --- |
# | `pan & zoom` | mouse and mousewheel events
# | `focus` by balancing to the center of mass | _first_ mouse click
# | `collapsible`  | _second_ mouse click on the focused node
# | `reset button` | icon click in the top left corner

# %%
iplot(df)
